# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_name="C:\\Users\\wow\\Desktop\\hello guru job kosam\\data sets\\visadataset.csv"
visa_dataset=pd.read_csv(file_name)

# %% [markdown]
# # scatter plots

# %% [markdown]
# - it provides the relation between two numerical variables
# - one varaible with another variable

# %%
x=[i for i in range(-10,10)]
y=[i*i for i in range(-10,10)]
plt.scatter(x,y)

# %%
visa_dataset.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
for key,value in dict(visa_dataset.dtypes).items():
    if value=="O":
        print(key,value)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# region_of_employment object
# unit_of_wage object
# full_time_position object
# case_status object

# %%
num_col=[]
for key,value in dict(visa_dataset.dtypes).items():
    if value!="O":
        num_col.append(key)
num_col
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
col1=visa_dataset["no_of_employees"]
col2=visa_dataset['yr_of_estab']
plt.scatter(col1,col2)

# %% [markdown]
# # pearson correlation coefficeint(r)

# %% [markdown]
# - r will vary from -1 to 1
# - -1 to 0 === negatively related numbers
# - 0 to 1 ==== positively realted numbers
# - 0 ========= no relation

# %%
difference between corelation and covariance

co variance: will explain the weather the both features are related or not

correlation: will explain the strength of the relation

# %%
visa_dataset.corr()
# Out:
# C:\Users\wow\AppData\Local\Temp\ipykernel_12664\411864502.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   visa_dataset.corr()
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
plt.subplot(1,4,1)
plt.subplot(1,4,2)
plt.subplot(1,4,3)
plt.subplot(1,4,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(1,3,1)
col1=visa_dataset["no_of_employees"]
col2=visa_dataset['yr_of_estab']
plt.scatter(col1,col2)

plt.subplot(1,3,2)
col1=visa_dataset["no_of_employees"]
col2=visa_dataset['prevailing_wage']
plt.scatter(col1,col2)

plt.subplot(1,3,3)
col2=visa_dataset["prevailing_wage"]
col1=visa_dataset['yr_of_estab']
plt.scatter(col1,col2)

# %%
plt.subplot(1,9,1)
# Out:
# <Axes: >

# %%
plt.subplot(9,1,9)
# Out:
# <Axes: >

# %%
corr_val=visa_dataset.corr()
sns.heatmap(corr_val,annot=True)
# Out:
# C:\Users\wow\AppData\Local\Temp\ipykernel_12664\2233431826.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_val=visa_dataset.corr()
# <Axes: >

# %%
corr_val.values
# Out:
# array([[ 1.        , -0.01777028, -0.00952252],
#        [-0.01777028,  1.        ,  0.01234176],
#        [-0.00952252,  0.01234176,  1.        ]])

# %%
col2=visa_dataset["prevailing_wage"]
col1=visa_dataset['yr_of_estab']
sns.jointplot(data=visa_dataset,x=col1,y=col2)

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_compat',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_oldcore',
#  '_orig_rc_params',
#  '_statistics',
#  '_stats',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
# ...
